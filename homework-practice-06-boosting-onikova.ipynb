# %% [markdown]
# # Машинное обучение, ФКН ВШЭ
#
# # Практическое задание 6. Бустинговое
#
# ## Общая информация
#
# Дата выдачи: 12.12.2023
#
# Мягкий дедлайн: 24.12.2023 23:59 MSK
#
# Жёсткий дедлайн: 24.12.2023 23:59 MSK
#
# ## Оценивание и штрафы
#
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов.
#
# Сдавать задание после указанного срока сдачи нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Неэффективная реализация кода может негативно отразиться на оценке.
#
# ## Формат сдачи
# Задания сдаются через систему anytask. Посылка должна содержать:
# * Ноутбук homework-practice-06-Username.ipynb
#
# Username — ваша фамилия на латинице

# %% [markdown]
# ## О задании
#
# В этом задании вам предстоит вручную запрограммировать один из самых мощных алгоритмов машинного обучения — бустинг.

# %%
from warnings import filterwarnings

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.sparse import load_npz
from sklearn.model_selection import train_test_split


sns.set(style='darkgrid')
filterwarnings('ignore')

# %%
x = load_npz('data/x.npz')
y = np.load('data/y.npy')

# %% [markdown]
# Разделим на обучающую, валидационную и тестовую выборки (`random_state` оставьте равным 1337 для воспроизводимости).

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1337)

x_test, x_valid, y_test, y_valid = train_test_split(x_test, y_test, test_size=0.5, random_state=1337)

x_train.shape, x_valid.shape, x_test.shape
# Out:
# ((18825, 169), (2354, 169), (2353, 169))

# %% [markdown]
# ## Задание 1. Реализация градиентного бустингового (4 балла)
#
# Вам нужно дописать код в файлике `boosting.py`. Для вас уже подготовлен шаблон класса `Boosting`, вы можете менять его по своему усмотрению.
#
# ### Инструкции для функций:
#
# #### `__init__`
#
# В `__init__` приходит кучка параметров, распишем что есть что:
#
#  - `base_model_class` - класс базовой модели нашего бустинга
#  - `base_model_params` - словарь с гиперпараметрами для базовой модели
#  - `n_estimators` - какое количество базовых моделей нужно обучить
#  - `learning_rate` - темп обучения, должен быть из полуинтервала $(0, 1]$
#  - `subsample` - доля объектов, на которой будет обучаться базовая модель (какую часть составляет бутстрапная выборка от исходной обучающей)
#  - `early_stopping_rounds` - число итераций, после которых при отсутствии улучшения качества на валидационной выборке обучение останавливается
#  - `plot` - строить ли после обучения всех базовых моделей график с качеством
#
# #### `fit`
#
# В `fit` приходит две выборки, обучающая и валидационная. На обучающей мы обучаем новые базовые модели, на валидационной считаем качество для ранней остановки (если это предусматривают параметры).
#
# Сначала нам нужно сделать какую-то нулевую модель, сделать предсказания для обучающей и валидационной выборок (в шаблоне это нулевая модель, соответственно предсказания это просто `np.zeros`). После этого нужно обучить `n_estimators` базовых моделей (как и на что обучаются базовые модели смотрите в лекциях и семинарах). После каждой обученной базовой модели мы должны обновить текущие предсказания, посчитать ошибку на обучающей и валидационной выборках (используем `loss_fn` для этого), проверить на раннюю остановку.
#
# После всего цикла обучения надо нарисовать график (если `plot`).
#
#
# #### `fit_new_base_model`
#
# В `fit_new_base_model` приходит обучающая выборка (целиком) и текущие предсказания для неё. Мы должны сгенерировать бутстрап выборку для обучения базовой модели и обучить базовую модель. После обучения модели запускаем поиск оптимальной гаммы, добавляем новую модель и гамму (не забываем про темп обучения) в соответствующие списки.
#
# #### `predict_proba`
#
# В `predict_proba` приходит выборка, нужно предсказать вероятности для неё. Суммируем предсказания базовых моделей на этой выборке (не забываем про гаммы) и накидываем сигмоиду.

# %%
# %load_ext autoreload

# %%
# %autoreload 2

from boosting import Boosting

# %% [markdown]
# ### Проверка кода
#
# У автора задания всё учится около одной секунды.

# %%
boosting = Boosting()

# %time boosting.fit(x_train, y_train, x_valid, y_valid)

assert len(boosting.models) == boosting.n_estimators
assert len(boosting.gammas) == boosting.n_estimators

assert boosting.predict_proba(x_test).shape == (x_test.shape[0], 2)

print(f'Train ROC-AUC {boosting.score(x_train, y_train):.4f}')
print(f'Valid ROC-AUC {boosting.score(x_valid, y_valid):.4f}')
print(f'Test ROC-AUC {boosting.score(x_test, y_test):.4f}')
# Out:
# CPU times: user 567 ms, sys: 7.9 ms, total: 575 ms
# Wall time: 655 ms
# Train ROC-AUC 0.9897
# Valid ROC-AUC 0.9211
# Test ROC-AUC 0.9190

# %% [markdown]
# ## Задание 2. Обучение градиентного бустингового (1 балл)
#
# Оцените качество на тестовой выборке вашей имплементации бустинга для различной максимальной глубины решающего дерева в качестве базовой модели. Здесь и далее мы будем использовать метрику ROC-AUC.
#
# Перебирайте максимальную глубину от 1 до 30 с шагом 2 (остальные параметры бустинга стоит оставить равными по умолчанию). Постройте график зависимости качества на обучающей и тестовой выборке в зависимости от глубины.

# %%
depths = range(1, 30, 2)
results = {'train': [], 'test': []}

for max_depth in depths:
    boosting = Boosting(base_model_params={'max_depth': max_depth})
    boosting.fit(x_train, y_train, x_valid, y_valid)
    results['train'].append(boosting.score(x_train, y_train))
    results['test'].append(boosting.score(x_test, y_test))

plt.figure(figsize=(10, 5))
line1, = plt.plot(depths, results['train'], 'b-', label='Training Score')
line2, = plt.plot(depths, results['test'], 'r-', label='Test Score')
plt.legend(handles=[line1, line2])
plt.xlabel('Tree Maximum Depth')
plt.ylabel('ROC AUC Score')
plt.title('Boosting Performance by Tree Depth')
plt.xticks(depths)
plt.grid(True)
plt.show()

# %% [markdown]
# **Какая из моделей имеет лучшее качество? Как вы можете это объяснить?**
#
# с увеличением глубины дерева модель переобучается
# лучшая модель с глубиной 9

# %% [markdown]
# ## Задание 3. Подбираем гиперпараметры и ищем лучшую модель (3 балла)
#
# Подберите по валидационной выборке основные гиперпараметры для вашей модели бустинга. Следует подобрать все основные параметры для самого градиентного бустинга и для самих базовых моделей. Существуют библиотеки для подбора гиперпараметров, попробуйте использовать какую-нибудь из следующих двух - [Hyperopt](https://github.com/hyperopt/hyperopt), [Optuna](https://optuna.org/).

# %%
import optuna
import numpy as np

def objective(trial):
    n_estimators = trial.suggest_int('n_estimators', 2, 30)
    learning_rate = trial.suggest_float('learning_rate', 0, 1)
    max_depth = trial.suggest_int('max_depth', 1, 15)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 2, 20)
    subsample = trial.suggest_float('subsample', 0.1, 1)

    model = Boosting(
        base_model_params={
            'max_depth': max_depth,
            'min_samples_split': min_samples_split,
            'min_samples_leaf': min_samples_leaf
        },
        n_estimators=n_estimators,
        learning_rate=learning_rate,
        subsample=subsample
    )

    scores = []
    for _ in range(3):
        model.fit(x_train, y_train, x_valid, y_valid)
        scores.append(model.score(x_valid, y_valid))

    return np.mean(scores)


study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

best_trial = study.best_trial

print('ROC-AUC:', best_trial.value)
print("Best hyperparameters:", best_trial.params)
# Out:
# [I 2023-12-24 13:37:35,643] A new study created in memory with name: no-name-ef6280b6-e31c-44af-97fa-e16828e78f91
# [I 2023-12-24 13:37:37,203] Trial 0 finished with value: 0.9200079606247068 and parameters: {'n_estimators': 22, 'learning_rate': 0.5539831710586707, 'max_depth': 3, 'min_samples_split': 11, 'min_samples_leaf': 17, 'subsample': 0.29414171783413673}. Best is trial 0 with value: 0.9200079606247068.
# [I 2023-12-24 13:37:38,040] Trial 1 finished with value: 0.9349667247483636 and parameters: {'n_estimators': 8, 'learning_rate': 0.3297967607330381, 'max_depth': 11, 'min_samples_split': 19, 'min_samples_leaf': 11, 'subsample': 0.3592433891537289}. Best is trial 1 with value: 0.9349667247483636.
# [I 2023-12-24 13:37:39,206] Trial 2 finished with value: 0.9188237112741017 and parameters: {'n_estimators': 15, 'learning_rate': 0.24208175851520297, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 12, 'subsample': 0.5858747551984046}. Best is trial 1 with value: 0.9349667247483636.
# [I 2023-12-24 13:37:41,995] Trial 3 finished with value: 0.9359338661524189 and parameters: {'n_estimators': 21, 'learning_rate': 0.04182687051195155, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 17, 'subsample': 0.8068698778184072}. Best is trial 3 with value: 0.9359338661524189.
# [I 2023-12-24 13:37:43,562] Trial 4 finished with value: 0.9359266824335991 and parameters: {'n_estimators': 17, 'learning_rate': 0.7540204762978311, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 3, 'subsample': 0.252509404970345}. Best is trial 3 with value: 0.9359338661524189.
# [I 2023-12-24 13:37:44,988] Trial 5 finished with value: 0.9269423777949655 and parameters: {'n_estimators': 22, 'learning_rate': 0.3808550332553724, 'max_depth': 4, 'min_samples_split': 12, 'min_samples_leaf': 13, 'subsample': 0.14671354070548948}. Best is trial 3 with value: 0.9359338661524189.
# [I 2023-12-24 13:37:45,280] Trial 6 finished with value: 0.9164274089204228 and parameters: {'n_estimators': 4, 'learning_rate': 0.31036395215861723, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 13, 'subsample': 0.5372272331095961}. Best is trial 3 with value: 0.9359338661524189.
# [I 2023-12-24 13:37:51,167] Trial 7 finished with value: 0.937288396245416 and parameters: {'n_estimators': 29, 'learning_rate': 0.7191102442791163, 'max_depth': 12, 'min_samples_split': 19, 'min_samples_leaf': 10, 'subsample': 0.9202164903942563}. Best is trial 7 with value: 0.937288396245416.
# [I 2023-12-24 13:37:53,073] Trial 8 finished with value: 0.9341468495801116 and parameters: {'n_estimators': 27, 'learning_rate': 0.2701589007901516, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 17, 'subsample': 0.11877280908477506}. Best is trial 7 with value: 0.937288396245416.
# [I 2023-12-24 13:37:54,327] Trial 9 finished with value: 0.9355839924395352 and parameters: {'n_estimators': 9, 'learning_rate': 0.37038349746745003, 'max_depth': 12, 'min_samples_split': 12, 'min_samples_leaf': 3, 'subsample': 0.5672480951540992}. Best is trial 7 with value: 0.937288396245416.
# [I 2023-12-24 13:38:01,795] Trial 10 finished with value: 0.93785085482263 and parameters: {'n_estimators': 30, 'learning_rate': 0.971553686785504, 'max_depth': 15, 'min_samples_split': 20, 'min_samples_leaf': 7, 'subsample': 0.9966269966715796}. Best is trial 10 with value: 0.93785085482263.
# [I 2023-12-24 13:38:08,757] Trial 11 finished with value: 0.9385572538398973 and parameters: {'n_estimators': 28, 'learning_rate': 0.9486773161784275, 'max_depth': 15, 'min_samples_split': 20, 'min_samples_leaf': 7, 'subsample': 0.9905714048792971}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:38:16,598] Trial 12 finished with value: 0.9383579721585664 and parameters: {'n_estimators': 30, 'learning_rate': 0.9889742765396492, 'max_depth': 15, 'min_samples_split': 17, 'min_samples_leaf': 7, 'subsample': 0.9922297378563326}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:38:22,142] Trial 13 finished with value: 0.9365460786340506 and parameters: {'n_estimators': 25, 'learning_rate': 0.9959935489507543, 'max_depth': 15, 'min_samples_split': 16, 'min_samples_leaf': 6, 'subsample': 0.7848811515609986}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:38:27,716] Trial 14 finished with value: 0.9375456798046241 and parameters: {'n_estimators': 25, 'learning_rate': 0.7945927126174887, 'max_depth': 13, 'min_samples_split': 16, 'min_samples_leaf': 7, 'subsample': 0.8233457790307709}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:38:29,672] Trial 15 finished with value: 0.9353932247953239 and parameters: {'n_estimators': 17, 'learning_rate': 0.8546333764381071, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 8, 'subsample': 0.6816626652579044}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:38:34,989] Trial 16 finished with value: 0.9381612180820057 and parameters: {'n_estimators': 30, 'learning_rate': 0.6041487017976765, 'max_depth': 10, 'min_samples_split': 18, 'min_samples_leaf': 4, 'subsample': 0.9461556909646475}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:38:37,888] Trial 17 finished with value: 0.9331429913909782 and parameters: {'n_estimators': 25, 'learning_rate': 0.8810329278699573, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 9, 'subsample': 0.8760538872100027}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:38:40,094] Trial 18 finished with value: 0.9382726987555405 and parameters: {'n_estimators': 13, 'learning_rate': 0.6347708260719267, 'max_depth': 13, 'min_samples_split': 17, 'min_samples_leaf': 5, 'subsample': 0.6793319636459956}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:38:41,852] Trial 19 finished with value: 0.836189659755131 and parameters: {'n_estimators': 27, 'learning_rate': 0.8963750471823857, 'max_depth': 1, 'min_samples_split': 20, 'min_samples_leaf': 15, 'subsample': 0.7087194150317568}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:38:44,751] Trial 20 finished with value: 0.9374036018101908 and parameters: {'n_estimators': 20, 'learning_rate': 0.4945544228608974, 'max_depth': 14, 'min_samples_split': 13, 'min_samples_leaf': 9, 'subsample': 0.4304268777336369}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:38:47,044] Trial 21 finished with value: 0.9378187941516014 and parameters: {'n_estimators': 13, 'learning_rate': 0.6757617805110023, 'max_depth': 13, 'min_samples_split': 17, 'min_samples_leaf': 5, 'subsample': 0.7186044220988406}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:38:49,311] Trial 22 finished with value: 0.9329797613355756 and parameters: {'n_estimators': 10, 'learning_rate': 0.9301366209389241, 'max_depth': 13, 'min_samples_split': 17, 'min_samples_leaf': 2, 'subsample': 0.9921661101852836}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:38:51,885] Trial 23 finished with value: 0.9362877308202023 and parameters: {'n_estimators': 12, 'learning_rate': 0.8060154050467401, 'max_depth': 14, 'min_samples_split': 18, 'min_samples_leaf': 5, 'subsample': 0.8725254413275075}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:38:52,788] Trial 24 finished with value: 0.9327188859169578 and parameters: {'n_estimators': 6, 'learning_rate': 0.6522088867354471, 'max_depth': 11, 'min_samples_split': 15, 'min_samples_leaf': 6, 'subsample': 0.6700192676777084}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:38:55,247] Trial 25 finished with value: 0.9366902851377638 and parameters: {'n_estimators': 18, 'learning_rate': 0.4597509592527328, 'max_depth': 14, 'min_samples_split': 20, 'min_samples_leaf': 8, 'subsample': 0.49004869507214865}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:38:55,715] Trial 26 finished with value: 0.917629883631737 and parameters: {'n_estimators': 2, 'learning_rate': 0.8439872242697698, 'max_depth': 15, 'min_samples_split': 18, 'min_samples_leaf': 5, 'subsample': 0.9082205942786663}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:38:58,288] Trial 27 finished with value: 0.9358573728501725 and parameters: {'n_estimators': 14, 'learning_rate': 0.1904831145768559, 'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 2, 'subsample': 0.7602034449965053}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:39:01,816] Trial 28 finished with value: 0.9371620160069218 and parameters: {'n_estimators': 28, 'learning_rate': 0.9921456229975092, 'max_depth': 10, 'min_samples_split': 14, 'min_samples_leaf': 20, 'subsample': 0.6079875287189369}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:39:06,766] Trial 29 finished with value: 0.9363893671383178 and parameters: {'n_estimators': 24, 'learning_rate': 0.7474026202650818, 'max_depth': 14, 'min_samples_split': 16, 'min_samples_leaf': 10, 'subsample': 0.8405835847301832}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:39:11,061] Trial 30 finished with value: 0.933296643154621 and parameters: {'n_estimators': 19, 'learning_rate': 0.5539768207073956, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 7, 'subsample': 0.9580993962975376}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:39:16,451] Trial 31 finished with value: 0.9372436975505382 and parameters: {'n_estimators': 30, 'learning_rate': 0.6057384518648589, 'max_depth': 10, 'min_samples_split': 18, 'min_samples_leaf': 4, 'subsample': 0.9268190485165845}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:39:20,994] Trial 32 finished with value: 0.937979097506744 and parameters: {'n_estimators': 23, 'learning_rate': 0.570719851629221, 'max_depth': 11, 'min_samples_split': 19, 'min_samples_leaf': 4, 'subsample': 0.9540083444924344}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:39:26,132] Trial 33 finished with value: 0.9365424867746407 and parameters: {'n_estimators': 27, 'learning_rate': 0.657747590751067, 'max_depth': 10, 'min_samples_split': 17, 'min_samples_leaf': 4, 'subsample': 0.9978759714661656}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:39:30,354] Trial 34 finished with value: 0.9358963511763605 and parameters: {'n_estimators': 30, 'learning_rate': 0.9310271685463303, 'max_depth': 8, 'min_samples_split': 19, 'min_samples_leaf': 6, 'subsample': 0.8587574459404648}. Best is trial 11 with value: 0.9385572538398973.
# [I 2023-12-24 13:39:33,637] Trial 35 finished with value: 0.939619779066058 and parameters: {'n_estimators': 28, 'learning_rate': 0.12875079496448816, 'max_depth': 12, 'min_samples_split': 18, 'min_samples_leaf': 3, 'subsample': 0.38346845070549784}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:39:35,290] Trial 36 finished with value: 0.9365655012812294 and parameters: {'n_estimators': 15, 'learning_rate': 0.008788477519875729, 'max_depth': 14, 'min_samples_split': 20, 'min_samples_leaf': 3, 'subsample': 0.33593016730117675}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:39:37,255] Trial 37 finished with value: 0.9373158008023948 and parameters: {'n_estimators': 22, 'learning_rate': 0.20356387177916463, 'max_depth': 12, 'min_samples_split': 14, 'min_samples_leaf': 11, 'subsample': 0.24469803695265846}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:39:40,906] Trial 38 finished with value: 0.9369413162009622 and parameters: {'n_estimators': 28, 'learning_rate': 0.43357424535624767, 'max_depth': 15, 'min_samples_split': 15, 'min_samples_leaf': 8, 'subsample': 0.41949780264883607}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:39:42,070] Trial 39 finished with value: 0.9339680548006001 and parameters: {'n_estimators': 12, 'learning_rate': 0.8029440934452003, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 2, 'subsample': 0.23174678608903737}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:39:45,981] Trial 40 finished with value: 0.9385279868372987 and parameters: {'n_estimators': 26, 'learning_rate': 0.09955474412610454, 'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 12, 'subsample': 0.6259419744097185}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:39:49,803] Trial 41 finished with value: 0.938217756609753 and parameters: {'n_estimators': 26, 'learning_rate': 0.08118102975104335, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 15, 'subsample': 0.6149973089582015}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:39:53,157] Trial 42 finished with value: 0.9382526109492115 and parameters: {'n_estimators': 28, 'learning_rate': 0.1267920506029195, 'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 12, 'subsample': 0.4782298249169922}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:39:57,437] Trial 43 finished with value: 0.9386437245293933 and parameters: {'n_estimators': 26, 'learning_rate': 0.13858665956575655, 'max_depth': 14, 'min_samples_split': 12, 'min_samples_leaf': 14, 'subsample': 0.6443121701558422}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:39:59,352] Trial 44 finished with value: 0.937417836216 and parameters: {'n_estimators': 23, 'learning_rate': 0.14400861616712438, 'max_depth': 15, 'min_samples_split': 11, 'min_samples_leaf': 14, 'subsample': 0.18599197306083548}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:40:02,326] Trial 45 finished with value: 0.9389908045738471 and parameters: {'n_estimators': 26, 'learning_rate': 0.2663337272419139, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 12, 'subsample': 0.3619353999118989}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:40:04,386] Trial 46 finished with value: 0.9308217189894158 and parameters: {'n_estimators': 26, 'learning_rate': 0.3043188288013702, 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 13, 'subsample': 0.4028518729412337}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:40:06,719] Trial 47 finished with value: 0.9369242881267229 and parameters: {'n_estimators': 21, 'learning_rate': 0.23923730307385893, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 12, 'subsample': 0.31006159959385715}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:40:09,457] Trial 48 finished with value: 0.9362653814727634 and parameters: {'n_estimators': 24, 'learning_rate': 0.046738493944201695, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 15, 'subsample': 0.5310225839398778}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:40:12,223] Trial 49 finished with value: 0.938156162872466 and parameters: {'n_estimators': 26, 'learning_rate': 0.10857757418056024, 'max_depth': 11, 'min_samples_split': 12, 'min_samples_leaf': 11, 'subsample': 0.38323952817959883}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:40:15,693] Trial 50 finished with value: 0.9377260709660957 and parameters: {'n_estimators': 29, 'learning_rate': 0.17598300326936306, 'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 17, 'subsample': 0.46469529845377533}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:40:20,063] Trial 51 finished with value: 0.9387971102293761 and parameters: {'n_estimators': 29, 'learning_rate': 0.07629303340521829, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 13, 'subsample': 0.5410504874842519}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:40:24,080] Trial 52 finished with value: 0.9387923210834964 and parameters: {'n_estimators': 28, 'learning_rate': 0.06258066581484806, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 14, 'subsample': 0.5169776438215012}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:40:28,368] Trial 53 finished with value: 0.9386212421501243 and parameters: {'n_estimators': 29, 'learning_rate': 0.061821021836316305, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 14, 'subsample': 0.5381566771074323}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:40:32,683] Trial 54 finished with value: 0.9384042672354044 and parameters: {'n_estimators': 29, 'learning_rate': 0.016812354285345124, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 14, 'subsample': 0.5377650483041607}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:40:36,939] Trial 55 finished with value: 0.9386976024205408 and parameters: {'n_estimators': 29, 'learning_rate': 0.06134475186745634, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 16, 'subsample': 0.5666416740365974}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:40:41,330] Trial 56 finished with value: 0.9390232643403656 and parameters: {'n_estimators': 27, 'learning_rate': 0.15961834994141835, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 16, 'subsample': 0.5865634374790444}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:40:45,206] Trial 57 finished with value: 0.9377299288891656 and parameters: {'n_estimators': 27, 'learning_rate': 0.24545384252809296, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 18, 'subsample': 0.5867850202252912}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:40:48,475] Trial 58 finished with value: 0.9377610583373842 and parameters: {'n_estimators': 24, 'learning_rate': 0.15302677858911395, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 16, 'subsample': 0.5122479134843916}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:40:51,873] Trial 59 finished with value: 0.9381907511482641 and parameters: {'n_estimators': 28, 'learning_rate': 0.06395850007664602, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 18, 'subsample': 0.45315274775621533}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:40:56,256] Trial 60 finished with value: 0.9371187806621739 and parameters: {'n_estimators': 29, 'learning_rate': 0.344483346558585, 'max_depth': 15, 'min_samples_split': 4, 'min_samples_leaf': 16, 'subsample': 0.571534337228618}. Best is trial 35 with value: 0.939619779066058.
# [I 2023-12-24 13:41:00,408] Trial 61 finished with value: 0.9397002633232043 and parameters: {'n_estimators': 25, 'learning_rate': 0.1536106609034053, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 13, 'subsample': 0.6525913193009596}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:41:03,224] Trial 62 finished with value: 0.9380706234057797 and parameters: {'n_estimators': 25, 'learning_rate': 0.21384083520303698, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 13, 'subsample': 0.35808246964402424}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:41:06,835] Trial 63 finished with value: 0.9377568013188243 and parameters: {'n_estimators': 27, 'learning_rate': 0.28242001113111426, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 16, 'subsample': 0.4973462296295866}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:41:12,469] Trial 64 finished with value: 0.9387206169271297 and parameters: {'n_estimators': 30, 'learning_rate': 0.02961931763596736, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 13, 'subsample': 0.7301548833257768}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:41:18,674] Trial 65 finished with value: 0.9381634796231154 and parameters: {'n_estimators': 30, 'learning_rate': 0.0258251790733367, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 12, 'subsample': 0.7565000279825895}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:41:23,230] Trial 66 finished with value: 0.9386662069086622 and parameters: {'n_estimators': 27, 'learning_rate': 0.09592657045822267, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 10, 'subsample': 0.6568667853590565}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:41:24,849] Trial 67 finished with value: 0.8405573607974887 and parameters: {'n_estimators': 25, 'learning_rate': 0.17728957401178672, 'max_depth': 1, 'min_samples_split': 6, 'min_samples_leaf': 13, 'subsample': 0.7193314218930095}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:41:28,472] Trial 68 finished with value: 0.9379568811911351 and parameters: {'n_estimators': 28, 'learning_rate': 0.11397789575724346, 'max_depth': 15, 'min_samples_split': 3, 'min_samples_leaf': 13, 'subsample': 0.44283558361263464}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:41:31,612] Trial 69 finished with value: 0.938108138381838 and parameters: {'n_estimators': 30, 'learning_rate': 0.0014029803506636213, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 11, 'subsample': 0.29842811769468813}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:41:33,278] Trial 70 finished with value: 0.8971858180619444 and parameters: {'n_estimators': 23, 'learning_rate': 0.15881571535453667, 'max_depth': 2, 'min_samples_split': 5, 'min_samples_leaf': 15, 'subsample': 0.7394303706762422}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:41:37,663] Trial 71 finished with value: 0.9389172379718606 and parameters: {'n_estimators': 29, 'learning_rate': 0.07026359125990586, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 17, 'subsample': 0.5848535300552345}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:41:42,212] Trial 72 finished with value: 0.9379970568037933 and parameters: {'n_estimators': 27, 'learning_rate': 0.03955541123003762, 'max_depth': 14, 'min_samples_split': 6, 'min_samples_leaf': 18, 'subsample': 0.6965855642802659}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:41:46,690] Trial 73 finished with value: 0.9375599142104335 and parameters: {'n_estimators': 29, 'learning_rate': 0.07492634193520338, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 14, 'subsample': 0.6290911245603676}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:41:50,793] Trial 74 finished with value: 0.937009561529749 and parameters: {'n_estimators': 28, 'learning_rate': 0.1306300553975049, 'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 20, 'subsample': 0.5816251391074989}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:41:54,468] Trial 75 finished with value: 0.9388650894945031 and parameters: {'n_estimators': 25, 'learning_rate': 0.09128359398108318, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 15, 'subsample': 0.5153738708825154}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:41:57,658] Trial 76 finished with value: 0.9374351303538994 and parameters: {'n_estimators': 24, 'learning_rate': 0.2170707899022817, 'max_depth': 14, 'min_samples_split': 10, 'min_samples_leaf': 19, 'subsample': 0.5086170729778645}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:41:59,786] Trial 77 finished with value: 0.9372068477336297 and parameters: {'n_estimators': 22, 'learning_rate': 0.2463068904544406, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 15, 'subsample': 0.2712238111570054}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:42:03,454] Trial 78 finished with value: 0.9381483139944963 and parameters: {'n_estimators': 25, 'learning_rate': 0.09756501170844248, 'max_depth': 13, 'min_samples_split': 11, 'min_samples_leaf': 17, 'subsample': 0.6023439960347519}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:42:06,689] Trial 79 finished with value: 0.9383320309517176 and parameters: {'n_estimators': 26, 'learning_rate': 0.16517839630538894, 'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 16, 'subsample': 0.3929526613920369}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:42:09,087] Trial 80 finished with value: 0.9368689468854455 and parameters: {'n_estimators': 21, 'learning_rate': 0.08094831602738238, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 12, 'subsample': 0.36287541769626186}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:42:14,562] Trial 81 finished with value: 0.9372346513860985 and parameters: {'n_estimators': 27, 'learning_rate': 0.04124575039333912, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 14, 'subsample': 0.8056190206683459}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:42:19,422] Trial 82 finished with value: 0.9369659270895111 and parameters: {'n_estimators': 28, 'learning_rate': 0.12704790271566802, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 13, 'subsample': 0.6591761869170273}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:42:23,768] Trial 83 finished with value: 0.9388469971656238 and parameters: {'n_estimators': 30, 'learning_rate': 0.392509624940678, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 15, 'subsample': 0.5557340813665638}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:42:27,869] Trial 84 finished with value: 0.9376407975630697 and parameters: {'n_estimators': 29, 'learning_rate': 0.3252463441522625, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 17, 'subsample': 0.5489642910287476}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:42:31,735] Trial 85 finished with value: 0.9387872658739567 and parameters: {'n_estimators': 28, 'learning_rate': 0.3932034720194306, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 15, 'subsample': 0.5186404876102246}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:42:35,422] Trial 86 finished with value: 0.9385343723651385 and parameters: {'n_estimators': 26, 'learning_rate': 0.27746673474676525, 'max_depth': 13, 'min_samples_split': 11, 'min_samples_leaf': 14, 'subsample': 0.5586776794629791}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:42:39,357] Trial 87 finished with value: 0.938175186424155 and parameters: {'n_estimators': 30, 'learning_rate': 0.391386244567866, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 15, 'subsample': 0.4818924364374253}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:42:41,962] Trial 88 finished with value: 0.9341363400655421 and parameters: {'n_estimators': 25, 'learning_rate': 0.43055128205234994, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 16, 'subsample': 0.6029228826187565}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:42:45,753] Trial 89 finished with value: 0.9381802416336947 and parameters: {'n_estimators': 29, 'learning_rate': 0.19722758754032416, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 9, 'subsample': 0.4264472629274919}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:42:47,073] Trial 90 finished with value: 0.9353487921641058 and parameters: {'n_estimators': 8, 'learning_rate': 0.18057402055614113, 'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 12, 'subsample': 0.639214304936808}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:42:50,942] Trial 91 finished with value: 0.9378939571355479 and parameters: {'n_estimators': 28, 'learning_rate': 0.5042254563819063, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 15, 'subsample': 0.5174597438474797}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:42:54,386] Trial 92 finished with value: 0.937913512814557 and parameters: {'n_estimators': 27, 'learning_rate': 0.3600992797631764, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 15, 'subsample': 0.4632461389911002}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:42:58,064] Trial 93 finished with value: 0.9370265896039882 and parameters: {'n_estimators': 27, 'learning_rate': 0.30226353525586275, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 14, 'subsample': 0.5220451173140535}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:43:02,578] Trial 94 finished with value: 0.9374578787968283 and parameters: {'n_estimators': 29, 'learning_rate': 0.40479439910677106, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 17, 'subsample': 0.5902244723124013}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:43:06,603] Trial 95 finished with value: 0.9383336273336775 and parameters: {'n_estimators': 28, 'learning_rate': 0.4768353140072621, 'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 16, 'subsample': 0.5485933079536304}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:43:09,304] Trial 96 finished with value: 0.9376781795072979 and parameters: {'n_estimators': 26, 'learning_rate': 0.22552330180998986, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 13, 'subsample': 0.3254532460198281}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:43:14,657] Trial 97 finished with value: 0.9385061696171797 and parameters: {'n_estimators': 30, 'learning_rate': 0.11418398540532447, 'max_depth': 15, 'min_samples_split': 9, 'min_samples_leaf': 15, 'subsample': 0.6936520001027561}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:43:17,045] Trial 98 finished with value: 0.9376107323694911 and parameters: {'n_estimators': 24, 'learning_rate': 0.5275764906732716, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 11, 'subsample': 0.40732574312859293}. Best is trial 61 with value: 0.9397002633232043.
# [I 2023-12-24 13:43:17,704] Trial 99 finished with value: 0.9344061286167694 and parameters: {'n_estimators': 5, 'learning_rate': 0.2641589907735795, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 18, 'subsample': 0.4956968409619431}. Best is trial 61 with value: 0.9397002633232043.
# ROC-AUC: 0.9397002633232043
# Best hyperparameters: {'n_estimators': 25, 'learning_rate': 0.1536106609034053, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 13, 'subsample': 0.6525913193009596}

# %%
Best_hyperparameters = {'n_estimators': 25, 'learning_rate': 0.1536106609034053, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 13, 'subsample': 0.6525913193009596}

# %% [markdown]
# ## Задание 4. Интерпретация бустингового (2 балл)
#
# Постройте калибровочную кривую для вашей лучшей модели бустинга. Насколько хорошо бустинг оценивает вероятности? Постройте также калибровочную кривую для логистической регрессии, сравните их между собой. Проанализируйте полученные результаты.

# %%
def plot_calibration_curve(y_test, preds, ax, title):
    bin_middle_points = []
    bin_real_ratios = []
    n_bins = 10
    y = (y_test + 1) / 2
    for i in range(n_bins):
        l = 1.0 / n_bins * i
        r = 1.0 / n_bins * (i + 1)
        bin_middle_points.append((l + r) / 2)
        bin_real_ratios.append(np.mean(y[(preds >= l) & (preds < r)] == 1))
    ax.grid()
    ax.set_title(f'{title} Calibration curve', fontsize=15)
    ax.set_xlabel('probs for positive class')
    ax.set_ylabel('true ratios')
    ax.plot(bin_middle_points, bin_real_ratios)
    ax.plot([0,1], [0,1], '--')
    plt.ylim([-0.05, 1.05])

# %%
Best_hyperparameters
# Out:
# {'n_estimators': 25,
#  'learning_rate': 0.1536106609034053,
#  'max_depth': 14,
#  'min_samples_split': 7,
#  'min_samples_leaf': 13,
#  'subsample': 0.6525913193009596}

# %%
from sklearn.linear_model import LogisticRegression
f, ax = plt.subplots(1, 2, figsize=(20, 7))

model = Boosting(base_model_params=
    {
        'max_depth': Best_hyperparameters['max_depth'],
        'min_samples_split': Best_hyperparameters['min_samples_split'],
        'min_samples_leaf': Best_hyperparameters['min_samples_leaf']
    }, 
    n_estimators=Best_hyperparameters['n_estimators'],
    learning_rate=Best_hyperparameters['learning_rate'], 
    subsample=Best_hyperparameters['subsample'])
model.fit(x_train, y_train, x_valid, y_valid)
y_pred = model.predict_proba(x_test)[:, 1]
plot_calibration_curve(y_test, y_pred, ax[0], 'Boosting')

model = LogisticRegression()
model.fit(x_train, y_train)
y_pred_proba = model.predict_proba(x_test)[:, 1]
plot_calibration_curve(y_test, y_pred_proba, ax[1], 'Logistic regr.')
plt.show()

# %% [markdown]
# Модель не уверена в предсказаниях

# %% [markdown]
# Теперь попробуем оценить важность признаков для бустинга.
#
# Поскольку наша базовая модель - это дерево из `sklearn`, мы можем вычислить важность признака отдельно для каждого дерева и усреднить (воспользуйтесь `feature_importances_` у `DecisionTreeRegressor`), после этого нормировать значения, чтобы они суммировались в единицу (обратите внимание, что они должны быть неотрицательными - иначе вы что-то сделали не так).
#
# Допишите в вашей реализации бустинга функцию `feature_importances_` чтобы она возвращала описанные выше важности признаков.
#
# Нарисуйте столбчатую диаграмму важности признаков. На соседнем графике нарисуйте важность признаков для логистической регрессии, для этого используйте модули весов. Сравните графики. Проанализируйте полученные результаты.

# %%
um_features = x_train.shape[1]
logreg = LogisticRegression()
logreg.fit(x_train, y_train)

f, ax = plt.subplots(1, 2, figsize=(20, 7))

ax[0].bar(range(169), boosting.feature_importances_)
ax[0].set_title('Boosting Feature Importances', fontsize=15)
ax[0].set_xlabel('Feature index')
ax[0].set_ylabel('Importance')

ax[1].bar(range(169), np.abs(logreg.coef_[0]) / np.sum(np.abs(logreg.coef_[0])), color='orange')
ax[1].set_title('Logistic Regression Feature Importances', fontsize=15)
ax[1].set_xlabel('Feature index')
ax[1].set_ylabel('Normalized Coefficient')

for axis in ax:
    axis.set_xticks(range(169))
    axis.set_xticklabels(range(169), rotation=90, fontsize=8)


plt.tight_layout()

plt.show()

# %% [markdown]
# у бустинга важных признаков сильно сильно меньше чем у логреша

# %% [markdown]
# Кстати, чаще всего излишние признаки могут вредить качеству бустинга. Попробуйте отфильтровать на основании диаграммы хвост наименее важных признаков и снова обучить модель (с теми же гиперпараметрами). Стало ли лучше?

# %%
# YOUR CODE:
boosting = Boosting(base_model_params=
    {
        'max_depth': Best_hyperparameters['max_depth'],
        'min_samples_split': Best_hyperparameters['min_samples_split'],
        'min_samples_leaf': Best_hyperparameters['min_samples_leaf']
    },
    n_estimators=Best_hyperparameters['n_estimators'],
    learning_rate=Best_hyperparameters['learning_rate'],
    subsample=Best_hyperparameters['subsample'],
    plot=True)
boosting.fit(x_train, y_train, x_valid, y_valid)
f_imps_boosting = boosting.feature_importances_
idxs = np.argsort(f_imps_boosting)[140:]
print('ROC-AUC test: ', boosting.score(x_test, y_test))
# Out:
# ROC-AUC test:  0.9350877704003792

# %% [markdown]
# отбрасывание признаков не меняет качетсво значительно

# %% [markdown]
# ## Задание 5 (бонус). Блендинговое (1 балл)
#
# Реализуйте блендинг над вашей лучшей моделью и логистической регрессией. Улучшилось ли качество?

# %%
boosting = Boosting(base_model_params=
    {
        'max_depth': Best_hyperparameters['max_depth'],
        'min_samples_split': Best_hyperparameters['min_samples_split'],
        'min_samples_leaf': Best_hyperparameters['min_samples_leaf']
    },
    n_estimators=Best_hyperparameters['n_estimators'],
    learning_rate=Best_hyperparameters['learning_rate'],
    subsample=Best_hyperparameters['subsample'],
    blend=True)
boosting.fit(x_train, y_train, x_valid, y_valid)
print('ROC-AUC test: ', boosting.score(x_test, y_test))
# Out:
# ROC-AUC test:  0.927187332217539

# %%
from sklearn.metrics import roc_auc_score
model = LogisticRegression().fit(x_train, y_train)
y_logreg_pred = model.predict_proba(x_test)[:, 1]
roc_auc_score(y_test, y_logreg_pred)
# Out:
# 0.9378958878831345

# %%
boosting = Boosting(base_model_params=
{
    'max_depth': Best_hyperparameters['max_depth'],
    'min_samples_split': Best_hyperparameters['min_samples_split'],
    'min_samples_leaf': Best_hyperparameters['min_samples_leaf']
},
    n_estimators=Best_hyperparameters['n_estimators'],
    learning_rate=Best_hyperparameters['learning_rate'],
    subsample=Best_hyperparameters['subsample'],
    blend=True,
    base_model_class=LogisticRegression)
boosting.fit(x_train, y_train, x_valid, y_valid)
print('ROC-AUC test: ', boosting.score(x_test, y_test))
# Out:
# ROC-AUC test:  0.9373526860151498

# %% [markdown]
# качество +- не изменилось

# %% [markdown]
# ## Задание 6 (бонус). Катбустовое (1 балл)
#
# Запустите [CatBoost](https://catboost.ai/en/docs/concepts/python-quickstart) на наших данных, сравните с вашей реализацией. Где получилось лучше?

# %%
# YOUR CODE:

# %% [markdown]
# ## Социализационный бонус. Новогоднее 🎆 (0.5 балла)
#
# Сфотографируйтесь с наряженной новогодней или рождественской ёлкой! Приложите фотографию, опишите свои впечатления, чего вы ждете от нового 2024 года?
